# %%
# Updating The Beast csv
import pandas as pd
import numpy as np
import glob
import json

csv_files = glob.glob('C:/Users/pensh/Desktop/VSCode/DataBase/Data/Draft/Beast*.xlsx')
df = []
for f in csv_files:
    df.append(pd.read_excel(f, sheet_name = 'Combine'))
df = pd.concat(df)
df.rename(columns = {'SCHOOL' : 'Beast'}, inplace = True)

pd.DataFrame(df['Beast'].unique(), columns = ['Beast']).to_csv('C:/Users/pensh/Desktop/VSCode/DataBase/Data/Teams/Beast.csv', index = False)

# %%
# Creating Teams csv
#TODO: Add Canadian colleges
#TODO: Add NCJAA for Iowa Western CC
df = pd.DataFrame()

#_ Combine Torvik and Sports_Reference _#
Torvik = pd.read_csv('C:/Users/pensh/Desktop/VSCode/DataBase/Data/Teams/Torvik.csv')
Sports_Reference = pd.read_csv('C:/Users/pensh/Desktop/VSCode/DataBase/Data/Teams/Sports_Reference.csv')

# Abbreviate State in Sports_Reference in a test column to merge, then merge and delete
Sports_Reference["test"] = Sports_Reference["Sports_Reference"].str.replace("State", "St.")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Florida International", "FIU")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Louisiana-Monroe", "Louisiana Monroe")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Miami (FL)", "Miami FL")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Miami (OH)", "Miami OH")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Middle Tennessee St.", "Middle Tennessee")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Ole Miss", "Mississippi")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("North Carolina St.", "N.C. State")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Pennsylvania", "Penn")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Pitt", "Pittsburgh")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Saint Mary's (CA)", "Saint Mary's")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Sam Houston", "Sam Houston St.")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Southern Mississippi", "Southern Miss")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Texas Christian", "TCU")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("California-Santa Barbara", "UC Santa Barbara")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Nevada-Las Vegas", "UNLV")
Sports_Reference["test"] = Sports_Reference["test"].str.replace("Virginia Military Institute", "VMI")


# Remove defunct Sports Reference teams
teams_to_remove = ["Alameda Coast Guard", "Amarillo Field", "Birmingham-Southern", "Boston University", "Bradley", "Cal State Fullerton", "Cal State Los Angeles", "California-Santa Barbara", "Camp Grant", "Carlisle", "Colorado College", "Creighton", "Denver", "Del Monte Pre-Flight", "Detroit Mercy", "Drury", "Fort Benning", "Fort Riley", "Fort Warren", "George Washington", "Gonzaga", "Georgia Pre-Flight", "Great Lakes Navy", "Hampden-Sydney", "Haskell", "Haverford", "Iowa Pre-Flight", "Jacksonville Naval Air Station", "Lombard", "Long Beach State", "Loyola (LA)", "Loyola Marymount", "Lubbock Field", "Manhattan", "March Field", "Mare Island Marines", "Marquette", "Mississippi College", "Nashville", "New York University", "Norman Naval Air Station", "North Carolina Pre-Flight", "Oglethorpe", "Pacific", "Phillips", "Portland", "Quantico Marines", "Randolph Field", "Regis (CO)", "Saint Louis", "Saint Mary's (CA)", "Saint Mary's (CA) Pre-Flight", "San Francisco", "Santa Clara", "Second Air Force", "Southwestern (TX)", "Spring Hill", "Stevens", "Swarthmore", "Tampa", "Tennessee Medical College", "Texas-Arlington", "Vermont", "West Texas State", "West Virginia Wesleyan", "Western State", "Whitman", "Wichita State", "Xavier"]
Sports_Reference = Sports_Reference[~Sports_Reference['Sports_Reference'].isin(teams_to_remove)]

# Remove basketball only Torvik teams
teams_to_remove = ["American", "Bellarmine", "Belmont", "Binghamton", "Boston University", "Bradley", "Cal Baptist", "Cal St. Bakersfield", "Cal St. Fullerton", "Cal St. Northridge", "Canisius", "Cleveland St.", "Coppin St.", "Creighton", "DePaul", "Denver", "Detroit Mercy", "Drexel", "Evansville", "Fairfield", "Fairfield", "Fairleigh Dickinson", "Florida Gulf Coast", "George Mason", "George Washington", "Gonzaga", "Grand Canyon", "Green Bay", "High Point", "Hofstra", "IU Indy", "Illinois Chicago", "Iona", "Jacksonville", "La Salle", "Le Moyne", "Lipscomb", "Little Rock", "Long Beach St.", "Longwood", "Loyola Chicago", "Loyola MD", "Loyola Marymount", "Manhattan", "Marquette", "Maryland Eastern Shore", "Milwaukee", "Mount St. Mary's", "NJIT", "Nebraska Omaha", "New Orleans", "Niagara", "North Florida", "Northeastern", "Northern Kentucky", "Oakland", "Oral Roberts", "Pacific", "Pepperdine", "Portland", "Providence", "Purdue Fort Wayne", "Queens", "Quinnipiac", "Radford", "Rider", "SIU Edwardsville", "Saint Joseph's", "Saint Louis", "Saint Mary's", "Saint Peter's", "San Francisco", "Santa Clara", "Seattle", "Seton Hall", "Siena", "Southern Indiana", "St. Bonaventure", "St. John's", "Texas A&M Corpus Chris", "UC Irvine", "UC Riverside", "UC San Diego", "UC Santa Barbara", "UMBC", "UMKC", "UMass Lowell", "UNC Asheville", "UNC Greensboro", "UNC Wilmington", "USC Upstate", "UT Arlington", "Utah Valley", "VCU", "Vermont", "Wichita St.", "Winthrop", "Wright St.", "Xavier"]
Torvik = Torvik[~Torvik['Torvik'].isin(teams_to_remove)]

df = pd.merge(Torvik, Sports_Reference, how = 'outer', left_on = ['Torvik'], right_on = ['test'])
df.drop(['test'], axis = 1, inplace = True)

#_ Combine Beast _#
Beast = pd.read_csv('C:/Users/pensh/Desktop/VSCode/DataBase/Data/Teams/Beast.csv')

# Remove duplicate Beast teams
teams_to_remove = ["Ark. at Monticello", "Augustana", "Benedictine (Kan.)", "California U. of Penn.", "Cumberlands", "Detroit Mercy", "Georgetown College", "Illinois College", "Limestone", "Louisiana Monroe", "Minn.-Duluth", "Minn. State-Mankato", "Mississippi College", "Mississippi Valley", "Missouri Western St.", "SUNY Morrisville", "Southern Conn. St.", "UT-Chattanooga", "Wisc.-La Crosse", "Wisc.-Platteville", "Wisc.-River Falls", "Wisc.-Whitewater"]
Beast = Beast[~Beast['Beast'].isin(teams_to_remove)]

# Beast["Beast"] = Beast["Beast"].str.replace('-', '-')
Beast["test"] = Beast["Beast"]
Beast["test"] = Beast["test"].str.replace('Central Conn. State', 'Central Connecticut')
Beast["test"] = Beast["test"].str.replace('UConn', 'Connecticut')
Beast["test"] = Beast["test"].str.replace("Cumberland (Tenn.)", "Cumberland")
Beast["test"] = Beast["test"].str.replace("Grambling", "Grambling St.")
Beast["test"] = Beast["test"].str.replace("Long Island", "LIU")
Beast["test"] = Beast["test"].str.replace("Miami", "Miami FL")
Beast["test"] = Beast["test"].str.replace("Miami FL (OH)", "Miami (OH)")
Beast["test"] = Beast["test"].str.replace("NC Central", "North Carolina Central")
Beast["test"] = Beast["test"].str.replace('NC State', 'North Carolina State')
Beast["test"] = Beast["test"].str.replace("SE Louisiana", "Southeastern Louisiana")
Beast["test"] = Beast["test"].str.replace("SE Missouri State", "Southeast Missouri St.")
Beast["test"] = Beast["test"].str.replace("St. Thomas (Minn.)", "St. Thomas")
Beast["test"] = Beast["test"].str.replace("UMass", "Massachusetts")
Beast["test"] = Beast["test"].str.replace("UT Martin", "Tennessee Martin")
Beast["test"] = Beast["test"].str.replace("Washington (Mo.)", "Washington (MO)")
df = pd.merge(df, Beast, how = 'outer', left_on = ['Sports_Reference'], right_on = ['test'])
Beast["test"] = Beast["test"].str.replace("State", "St.")
df = pd.merge(df, Beast, how = 'outer', left_on = ['Torvik'], right_on = ['test']).rename({'Beast_x' : 'Beast'}, axis = 1)
df['Beast'] = df['Beast'].fillna(df['Beast_y'])
df = df.drop(['Beast_y', 'test_x', 'test_y'], axis = 1).drop_duplicates().reset_index(drop = True)
df = pd.concat([df.drop_duplicates(subset = ['Beast']), df[~df.index.isin(df.dropna(subset = 'Beast').index)]], ignore_index = True)

#_ Combine Wiki _#
Wiki_Cols = ['Wikipedia', 'Nickname', 'City', 'State', 'Conference', 'Division']
Wiki_Cols_fillna = ['Wikipedia_y', 'Nickname_y', 'City_y', 'State_y', 'Conference_y', 'Division_y']
Wiki_TEST = {'Wikipedia' : 'Wikipedia_y', 'Nickname' : 'Nickname_y', 'City' : 'City_y', 'State' : 'State_y', 'Conference' : 'Conference_y', 'Division' : 'Division_y'}
Wiki_Rename_x = {'Wikipedia_x' : 'Wikipedia', 'Nickname_x' : 'Nickname', 'City_x' : 'City', 'State_x' : 'State', 'Conference_x' : 'Conference', 'Division_x' : 'Division'}

def Wiki_fillna(df, Wiki_Cols):
    for c in Wiki_Cols:
        df[c] = df[c].fillna(df[c + '_y'])
    return df

Wikipedia = pd.read_csv('C:/Users/pensh/Desktop/VSCode/DataBase/Data/Teams/Wikipedia.csv', encoding='cp1252')
Wikipedia["Conference"] = Wikipedia["Conference"].str.replace('OVC–Big South', "OVC-Big South")
Wikipedia["Conference"] = Wikipedia["Conference"].str.replace('Appalachian Athletic Conference', "AAC")
Wikipedia["Conference"] = Wikipedia["Conference"].str.replace('Frontier Conference', "Frontier")
Wikipedia["Conference"] = Wikipedia["Conference"].str.replace('Great Plains Athletic Conference', "GPAC")
Wikipedia["Conference"] = Wikipedia["Conference"].str.replace('Heart of America Athletic Conference', "HAAC")
Wikipedia["Conference"] = Wikipedia["Conference"].str.replace('Kansas Collegiate Athletic Conference', "KCAC")
Wikipedia["Conference"] = Wikipedia["Conference"].str.replace('Mid-South Conference', "MSC")
Wikipedia["Conference"] = Wikipedia["Conference"].str.replace('Mid-States Football Association', "MSFA")
Wikipedia["Conference"] = Wikipedia["Conference"].str.replace('Sooner Athletic Conference', "SAC")
Wikipedia["Conference"] = Wikipedia["Conference"].str.replace('The Sun Conference', "TSC")
Wikipedia["City"] = Wikipedia["City"].str.replace(' & ', "")
Wikipedia["Wikipedia"] = Wikipedia["Wikipedia"].str.replace('?', "")
Wikipedia["Wikipedia"] = Wikipedia["Wikipedia"].str.replace('–', '-')
Wikipedia["Wikipedia"] = Wikipedia["Wikipedia"].str.replace(' ', ' ')
Wikipedia = Wikipedia[~((Wikipedia["Wikipedia"] == 'Texas') & (Wikipedia["Division"] == 'NAIA'))]
Wikipedia["Wikipedia"] = Wikipedia["Wikipedia"].str.replace(' College', '')
Wikipedia["Wikipedia"] = Wikipedia["Wikipedia"].str.replace(' University', '')
# Wikipedia.to_csv('C:/Users/pensh/Desktop/VSCode/DataBase/Data/Teams/Wikipedia.csv', index = False)
Wikipedia["test"] = Wikipedia["Wikipedia"].str.replace('-', ' ')
Wikipedia["test"] = Wikipedia["test"].str.replace('State', 'St.')
Wikipedia["test"] = Wikipedia["test"].str.replace("American International", "American Intl.")
Wikipedia["test"] = Wikipedia["test"].str.replace('Bluefield', 'Blueﬁeld')
Wikipedia["test"] = Wikipedia["test"].str.replace('Boston', 'Boston College')
Wikipedia["test"] = Wikipedia["test"].str.replace("California (PA)", "California (Pa.)")
Wikipedia["test"] = Wikipedia["test"].str.replace("Case Western Reserve", "Case Western")
Wikipedia["test"] = Wikipedia["test"].str.replace("Centenary", "Centenary (LA)")
Wikipedia["test"] = Wikipedia["test"].str.replace("California (PA)", "Central Conn. State")
Wikipedia["test"] = Wikipedia["test"].str.replace("Claremont Mudd Scripps", "Claremont M S")
Wikipedia["test"] = Wikipedia["test"].str.replace("Concordia (WI)", "Concordia (Wis.)")
Wikipedia["test"] = Wikipedia["test"].str.replace("Concordia Nebraska", "Concordia (Neb.)")
Wikipedia["test"] = Wikipedia["test"].str.replace("Concordia (Moorhead)", "Concordia St. Paul")
Wikipedia["test"] = Wikipedia["test"].str.replace("Cornell (IA)", "Cornell College")
Wikipedia["test"] = Wikipedia["test"].str.replace('IUP', 'Indiana Univ. of Pa.')
Wikipedia["test"] = Wikipedia["test"].str.replace('McNeese', 'McNeese St.')
Wikipedia["test"] = Wikipedia["test"].str.replace('Missouri Western', 'Missouri Western State')
Wikipedia["test"] = Wikipedia["test"].str.replace('Nicholls', 'Nicholls State')
Wikipedia["test"] = Wikipedia["test"].str.replace("Northwest Missouri St.", "NW Missouri State")
Wikipedia["test"] = Wikipedia["test"].str.replace("Northwestern Oklahoma St.", "NW Oklahoma State")
Wikipedia["test"] = Wikipedia["test"].str.replace("Northwestern (MN)", "Northwestern (Minn.)")
Wikipedia["test"] = Wikipedia["test"].str.replace("Union", "Union (NY)")
Wikipedia["test"] = Wikipedia["test"].str.replace("Mount Union (NY)", "Mount Union")
Wikipedia["test"] = Wikipedia["test"].str.replace("Saint Francis (PA)", "Saint Francis")
Wikipedia["test"] = Wikipedia["test"].str.replace('TCNJ', 'College of New Jersey')
Wikipedia["test"] = Wikipedia["test"].str.replace("Virginia Union (NY)", "Virginia Union")
Wikipedia["test"] = Wikipedia["test"].str.replace("ULM", "Louisiana Monroe")
Wikipedia["test"] = Wikipedia["test"].str.replace('UTRGV', 'UT Rio Grande Valley')
Wikipedia["test"] = Wikipedia["test"].str.replace('Washington (St. Louis)', 'Washington (MO)')
Wikipedia["test"] = Wikipedia["test"].str.replace('Wesleyan', 'Wesleyan (CT)')
Wikipedia["test"] = Wikipedia["test"].str.replace('Western Connecticut', 'Western Conn. State')
Wikipedia["test"] = Wikipedia["test"].str.replace('Westminster (PA)', 'Westminster (Pa.)')
# Wikipedia["test"] = Wikipedia["test"].str.replace('Wisconsin La Crosse', 'Wisc.-La Crosse')
# Wikipedia["test"] = Wikipedia["test"].str.replace('Wisconsin Platteville', 'Wisc.-Platteville')
# Wikipedia["test"] = Wikipedia["test"].str.replace('Wisconsin River Falls', 'Wisc.-River Falls')
# Wikipedia["test"] = Wikipedia["test"].str.replace('Wisconsin Whitewater', 'Wisc.-Whitewater')
df = pd.merge(df, Wikipedia, how = 'outer', left_on = ['Torvik'], right_on = ['test'])
Wikipedia["test"] = Wikipedia["test"].str.replace('St.', 'State')
Wikipedia["test"] = Wikipedia["test"].str.replace("Concordia State Paul", "Concordia St. Paul")
Wikipedia["test"] = Wikipedia["test"].str.replace('Missouri Southern', 'Mo. Southern State')
Wikipedia["test"] = Wikipedia["test"].str.replace('Minnesota State', 'Minn. St.-Mankato')
Wikipedia["test"] = Wikipedia["test"].str.replace("North Carolina Wesleyan (CT)", "NC Wesleyan")
Wikipedia["test"] = Wikipedia["test"].str.replace("Oklahoma Panhandle State", "Okla. Panhandle St.")
Wikipedia["test"] = Wikipedia["test"].str.replace('Cortland', 'SUNY Cortland')
Wikipedia["test"] = Wikipedia["test"].str.replace('Southern Connecticut', 'Southern Conn. State')
Wikipedia["test"] = Wikipedia["test"].str.replace('State Norbert', 'St. Norbert')
Wikipedia["test"] = Wikipedia["test"].str.replace('State Thomas', 'St. Thomas (Fla.)')
Wikipedia["test"] = Wikipedia["test"].str.replace('University of Saint Francis (IN)', 'St. Francis (Ind.)')
Wikipedia["test"] = Wikipedia["test"].str.replace('University of State Francis (IL)', 'St. Francis (Ill.)')
Wikipedia["test"] = Wikipedia["test"].str.replace('UT Permian Basin', 'Texas Permian Basin')
Wikipedia["test"] = Wikipedia["test"].str.replace('Wayne State (MI)', 'Wayne State')
df = pd.merge(df, Wikipedia, how = 'outer', left_on = ['Sports_Reference'], right_on = ['test']).rename(Wiki_Rename_x, axis = 1)
df = Wiki_fillna(df, Wiki_Cols)
Wiki_Cols_Remove = Wiki_Cols_fillna + [test for test in df.columns if (test == 'test' or 'test_' in test)]
df = df.drop(Wiki_Cols_Remove, axis = 1).drop_duplicates().reset_index(drop = True)
df['test'] = df['Beast'].str.replace('-', ' ')
# print(Wikipedia[Wikipedia['Wikipedia'] == 'Wisconsin-River Falls'])
# print(Beast[Beast['Beast'] == 'Wisc.-River Falls'])
# print(Wikipedia[Wikipedia['Wikipedia'] == 'Wisconsin-River Falls']['test'].iloc[0] == Beast[Beast['Beast'] == 'Wisc.-River Falls']['test'].iloc[0])
df = pd.merge(df, Wikipedia, how = 'outer', left_on = ['test'], right_on = ['test']).rename(Wiki_Rename_x, axis = 1)
df = Wiki_fillna(df, Wiki_Cols)
Wiki_Cols_Remove = Wiki_Cols_fillna + [test for test in df.columns if (test == 'test' or 'test_' in test)]
df = df.drop(Wiki_Cols_Remove, axis = 1).drop_duplicates().reset_index(drop = True)
df.sort_values(['Torvik', 'Sports_Reference', 'Beast', 'Wikipedia'], inplace = True)
df = pd.concat([df.drop_duplicates(subset = Wiki_Cols), df[~df.index.isin(df.dropna(subset = Wiki_Cols).index)]], ignore_index = True)

# Any extra edits
df.loc[(df['Wikipedia'] == 'Southwestern') & (df['City'] == 'Georgetown'), 'Sports_Reference'] = 'Southwestern (TX)'
df.loc[(df['Wikipedia'] == 'Georgetown') & (df['Nickname'] == 'Tigers'), 'Torvik'] = np.nan
df.loc[(df['Wikipedia'] == 'Georgetown') & (df['Nickname'] == 'Tigers'), 'Sports_Reference'] = np.nan
df.loc[(df['Wikipedia'] == 'Georgetown') & (df['Nickname'] == 'Tigers'), 'Beast'] = 'Georgetown College'
df.loc[(df['Wikipedia'] == 'Illinois') & (df['Nickname'] == 'Blueboys'), 'Torvik'] = np.nan
df.loc[(df['Wikipedia'] == 'Illinois') & (df['Nickname'] == 'Blueboys'), 'Sports_Reference'] = np.nan
df.loc[(df['Wikipedia'] == 'Illinois') & (df['Nickname'] == 'Blueboys'), 'Beast'] = 'Illinois College'
df.loc[df['Wikipedia'] == 'Augustana (SD)', 'Beast'] = 'Augustana'
df.loc[df['Wikipedia'] == 'Bethune-Cookman', 'Beast'] = 'Bethune-Cookman'
df.loc[df['Wikipedia'] == 'Gardner-Webb', 'Beast'] = 'Gardner-Webb'
df.loc[df['Wikipedia'] == 'Saint Thomas', 'Beast'] = 'St. Thomas (Fla.)'
df.loc[df['Wikipedia'] == 'Minnesota State', 'Beast'] = 'Minn. State-Mankato'
df.loc[df['Wikipedia'] == 'West Virginia Wesleyan', 'Sports_Reference'] = 'West Virginia Wesleyan'
df.loc[df['Wikipedia'] == 'Wisconsin-La Crosse', 'Beast'] = 'Wisc.-La Crosse'
df.loc[df['Wikipedia'] == 'Wisconsin-Platteville', 'Beast'] = 'Wisc.-Platteville'
df.loc[df['Wikipedia'] == 'Wisconsin-River Falls', 'Beast'] = 'Wisc.-River Falls'
df.loc[df['Wikipedia'] == 'Wisconsin-Whitewater', 'Beast'] = 'Wisc.-Whitewater'
df.loc[df['Beast'] == 'Arkansas-Monticello', 'Other'] = 'Ark. at Monticello'
df.loc[df['Beast'] == 'Augustana (IL)', 'Other'] = 'Augustana'
df.loc[df['Beast'] == 'Augustana (SD)', 'Other'] = 'Augustana'
df.loc[(df['Wikipedia'] == 'Benedictine') & (df['State'] == 'Kansas'), 'Beast'] = 'Benedictine (Kan.)'
df.loc[df['Beast'] == 'California (Pa.)', 'Other'] = 'California U. of Penn.'
df.loc[df['Beast'] == 'Cumberland (Tenn.)', 'Other'] = 'Cumberlands'
df.loc[df['Beast'] == 'Louisiana-Monroe', 'Other'] = 'Louisiana Monroe'
df.loc[df['Beast'] == 'Minnesota Duluth', 'Other'] = 'Minn.-Duluth'
df.loc[df['Beast'] == 'Mississippi Valley St.', 'Other'] = 'Mississippi Valley'
df.loc[df['Beast'] == 'Missouri Western State', 'Other'] = 'Missouri Western St.'
df.loc[df['Beast'] == 'Morrisville', 'Other'] = 'SUNY Morrisville'
df.loc[df['Beast'] == 'Southern Connecticut', 'Other'] = 'Southern Conn. St.'
df.loc[df['Beast'] == 'Chattanooga', 'Other'] = 'UT-Chattanooga'
df.loc[df['Beast'] == 'UT Martin', 'Other'] = 'UT-Martin'
df.loc[df['Beast'] == 'UC Davis', 'Other'] = 'UC-Davis'
df.loc[df['Beast'] == 'Southern Conn. State', 'Other'] = 'Southern Conn. St.'
df.loc[df['Beast'].str.contains('(Can.)', na = False, regex = False), 'Conference'] = 'CAN'
df.loc[df['Beast'].str.contains('(Can.)', na = False, regex = False), 'Division'] = 'Canada'
df.loc[df['Beast'].str.contains('(IPP)', na = False, regex = False), 'Conference'] = 'IPP'
df.loc[df['Beast'].str.contains('(IPP)', na = False, regex = False), 'Division'] = 'International Pathway Program'
df.loc[df['Beast'].str.contains('(England)', na = False, regex = False), 'Conference'] = 'IPP'
df.loc[df['Beast'].str.contains('(England)', na = False, regex = False), 'Division'] = 'International Pathway Program'
# df.loc[df['Beast'].str.contains('Iowa Western CC', na = False, regex = False), 'Conference'] = 'ICCAC'
# df.loc[df['Beast'].str.contains('Iowa Western CC', na = False, regex = False), 'Division'] = 'NJAAC'
# df.loc[df['Beast'].str.contains('Iowa Western CC', na = False, regex = False), 'Nickname'] = 'Reivers'
# df.loc[df['Beast'].str.contains('Iowa Western CC', na = False, regex = False), 'City'] = 'Council Bluffs'
# df.loc[df['Beast'].str.contains('Iowa Western CC', na = False, regex = False), 'State'] = 'Iowa'
df.loc[(df['Division'] == 'DIII') & (df['Conference'] == 'MAC'), 'Conference'] = 'MAC (DIII)'

df = df.sort_values(['Torvik', 'Sports_Reference', 'Beast', 'Wikipedia']).drop_duplicates()
df = df.drop_duplicates(subset = ['Torvik', 'Beast', 'Wikipedia', 'Conference'])

# Use state abreviations
with open('C:/Users/pensh/Desktop/VSCode/DataBase/Data/Generic/States.json', 'r') as f:
    f = json.load(f)
    df['State'] = df['State'].map(lambda x: f.get(x, x))

# Create column to be used
df['College'] = df["Beast"].fillna(df["Sports_Reference"]).fillna(df["Torvik"]).fillna(df["Wikipedia"])
df.loc[(df['Wikipedia'] == 'Northwestern') & (df['City'] == 'Orange City'), 'College'] = 'Northwestern (Ia.)'
df.to_csv('C:/Users/pensh/Desktop/VSCode/DataBase/Data/Teams/College_Teams.csv', index = False)
# df[df["Wikipedia"].isna()]

# %%
leagues = df[['Conference', 'Division']].copy()
leagues = leagues.drop_duplicates()
leagues = leagues.dropna()
leagues = leagues.sort_values(['Division', 'Conference'])
leagues = dict(zip(leagues['Conference'], leagues['Division']))

with open('C:/Users/pensh/Desktop/VSCode/DataBase/Data/Leagues/Conference_To_Division.json', 'w+') as f:
    json.dump(leagues, f)
